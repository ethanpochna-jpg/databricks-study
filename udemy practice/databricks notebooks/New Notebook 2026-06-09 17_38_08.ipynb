-- %%
SELECT
*
FROM workspace.udemy.payment
WHERE 
(customer_id = 322 OR customer_id = 346 or customer_id = 354)
AND
(amount < 2 OR amount > 10)
ORDER BY customer_id ASC, amount DESC

-- %%
SET TIME ZONE 'Europe/Berlin'

-- %%
SELECT
*
FROM workspace.udemy.payment
WHERE 
(payment_date BETWEEN (TIMESTAMP '2020-01-26 00:00:00' AT TIME ZONE 'Europe/Berlin') AND (TIMESTAMP '2020-01-27 23:59:59' AT TIME ZONE 'Europe/Berlin'))
AND
(amount BETWEEN 1.99 AND 3.99)
ORDER BY payment_date ASC

-- %%
SELECT
*
FROM workspace.udemy.payment
WHERE 
(payment_date BETWEEN '2020-01-26 0:00' AND '2020-01-27 23:59')
AND
(amount BETWEEN 1.99 AND 3.99)
ORDER BY payment_date ASC

-- %%
USE workspace.udemy;

-- %%
SELECT
current_catalog(),
current_schema()

-- %%
SELECT * FROM customer
WHERE customer_id IN (123, 212, 323, 243, 353, 432)

-- %%
SELECT 
*
FROM payment
WHERE customer_id IN (12,25,67,93,124,234)
AND amount IN (4.99,7.99,9.99)
AND payment_date BETWEEN '2020-01-01' AND '2020-02-01'

-- %%
SELECT
*
FROM film
WHERE description LIKE '%Drama%'

-- %%
SELECT
COUNT(*)
FROM film
WHERE description ILIKE '%Documentary%'

-- %%
SELECT
payment_id AS amount
FROM payment
ORDER BY payment_id

-- %%
SELECT
payment_id AS amount
FROM payment
ORDER BY amount

-- %%
SELECT
payment_id
FROM payment
ORDER BY amount

-- %%
SELECT
amount,
payment_id AS amount

FROM payment
ORDER BY amount

-- %%
SELECT 
COUNT(*) AS no_of_movies
FROM film
WHERE description LIKE '%Saga%'
AND (title LIKE 'A%' OR title LIKE '%R')

-- %%
SELECT
*
FROM customer
WHERE 
first_name LIKE '%ER%'
AND 
first_name LIKE '_A%'
ORDER BY last_name DESC

-- %%
SELECT
COUNT(*)
FROM payment
WHERE 
(amount = 0 OR amount BETWEEN 3.99 AND 7.99)
AND
(payment_date BETWEEN '2020-05-01' AND '2020-05-02')
