-- %%
CREATE SCHEMA IF NOT EXISTS workspace.udemy;
CREATE VOLUME IF NOT EXISTS workspace.udemy.raw;

-- %%
CREATE OR REPLACE TABLE workspace.udemy.actor AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/actor.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.address AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/address.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.category AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/category.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.city AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/city.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.country AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/country.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.customer AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/customer.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.film AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/film.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.film_actor AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/film_actor.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.film_category AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/film_category.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.inventory AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/inventory.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.language AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/language.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.payment AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/payment.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.rental AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/rental.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.staff AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/staff.csv',
	format => 'csv', header => true
);
CREATE OR REPLACE TABLE workspace.udemy.store AS
SELECT * FROM read_files(
	'/Volumes/workspace/udemy/raw/store.csv',
	format => 'csv', header => true
);
